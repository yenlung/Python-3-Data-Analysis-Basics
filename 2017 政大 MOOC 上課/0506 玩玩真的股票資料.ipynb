# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## 安裝 `pandas-datareader`
#
# 注意要安裝 pandas-datareader 套件
#
#     conda install pandas-datareader
#
# 如果之前裝過, 但有陣子沒用, 請更新
#
#     conda update pandas-datareader

# %%
import pandas_datareader.data as web

# %%
df = web.DataReader("AAPL", "yahoo", start="2012-9-1", end="2017-8-31")

# %%
df.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2012-08-31  95.321426  95.514282  93.892860  95.034286  85.865257  84580300
# 2012-09-04  95.108574  96.448570  94.928574  96.424286  87.121140  91973000
# 2012-09-05  96.510002  96.621429  95.657143  95.747147  86.509338  84093800
# 2012-09-06  96.167145  96.898575  95.828575  96.610001  87.288956  97799100
# 2012-09-07  96.864288  97.497147  96.538574  97.205711  87.827171  82416600

# %%
P = df["Adj Close"]

# %%
P.head()
# Out:
# Date
# 2012-08-31    85.865257
# 2012-09-04    87.121140
# 2012-09-05    86.509338
# 2012-09-06    87.288956
# 2012-09-07    87.827171
# Name: Adj Close, dtype: float64

# %%
P.plot()

# %% [markdown]
# ## 計算報酬率
#
# $$\frac{P_{t} - P_{t-1}}{P_{t-1}}$$

# %%
r = P.diff()/P

# %%
r[-100:].plot()

# %% [markdown]
# ## 移動平均

# %%
P.rolling(window=20).mean()
# Out:
# Date
# 2012-08-31           NaN
# 2012-09-04           NaN
# 2012-09-05           NaN
# 2012-09-06           NaN
# 2012-09-07           NaN
# 2012-09-10           NaN
# 2012-09-11           NaN
# 2012-09-12           NaN
# 2012-09-13           NaN
# 2012-09-14           NaN
# 2012-09-17           NaN
# 2012-09-18           NaN
# 2012-09-19           NaN
# 2012-09-20           NaN
# 2012-09-21           NaN
# 2012-09-24           NaN
# 2012-09-25           NaN
# 2012-09-26           NaN
# 2012-09-27           NaN
# 2012-09-28     87.867450
# 2012-10-01     87.829696
# 2012-10-02     87.741539
# 2012-10-03     87.749413
# 2012-10-04     87.688295
# 2012-10-05     87.508560
# 2012-10-08     87.349993
# 2012-10-09     87.190327
# 2012-10-10     87.003944
# 2012-10-11     86.649763
# 2012-10-12     86.252408
#                  ...
# 2017-07-21    145.840786
# 2017-07-24    146.130149
# 2017-07-25    146.474796
# 2017-07-26    146.959393
# 2017-07-27    147.194968
# 2017-07-28    147.484830
# 2017-07-31    147.719408
# 2017-08-01    148.045627
# 2017-08-02    148.695575
# 2017-08-03    149.335064
# 2017-08-04    149.943176
# 2017-08-07    150.627987
# 2017-08-08    151.352641
# 2017-08-09    152.115645
# 2017-08-10    152.522046
# 2017-08-11    152.973196
# 2017-08-14    153.516947
# 2017-08-15    154.122300
# 2017-08-16    154.648336
# 2017-08-17    155.053740
# 2017-08-18    155.444630
# 2017-08-21    155.730376
# 2017-08-22    156.112249
# 2017-08-23    156.468263
# 2017-08-24    156.933209
# 2017-08-25    157.480449
# 2017-08-28    158.146538
# 2017-08-29    158.818885
# 2017-08-30    159.160119
# 2017-08-31    159.612045
# Name: Adj Close, Length: 1258, dtype: float64

# %%
P.plot()
P.rolling(window=20).mean().plot()
P.rolling(window=60).mean().plot()
