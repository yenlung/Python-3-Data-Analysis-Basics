# %%
3+9
# Out:
# 12

# %% [markdown]
# 自由作筆記！

# %% [markdown]
# # 大標題
#
# ## 小標題
#
# 內文在這裡。

# %% [markdown]
# ## 分項說明
#
# * Python
# * Jupyter Notebook
# * Numpy
# * Pandas
# * Matplotlib

# %% [markdown]
# ## 連結
#
# [政大 MOOC 網](http://moocs.nccu.edu.tw)

# %% [markdown]
# ## 插入圖片
#
# ![台灣黑熊](bear.png)

# %% [markdown]
# ## 打數學符號
#
# 我們有一個函數 $f(x)=x^3 - 2x^2 + 5$, 我想給它積分:
#
# $$\int_a^b f(x) \, dx$$
