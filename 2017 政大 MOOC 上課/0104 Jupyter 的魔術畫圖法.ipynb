# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
pi
# Out:
# 3.141592653589793

# %%
sin(pi/2)
# Out:
# 1.0

# %%
plot([-2, 10, 3, 13, 5])

# %%
randn(10)
# Out:
# array([ 0.41718315,  1.27796657, -1.00770565,  1.2266901 , -1.18028148,
#        -0.42363828,  1.04770463, -1.0463822 , -0.89933164, -1.75324632])

# %%
plot(randn(100))

# %%
plot([-2, 1, 2.7, 3.3], [3, -5, 6, 0])
