# %%
1+1
# Out:
# 2

# %%
87 + (25*3 + 96 + 75**2)
# Out:
# 5883

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## 支援 Markdown 語法
#
# Matplotlib 的名稱: MATlab - PLOT - LIB

# %% [markdown]
# Markdown 語法有很多方便的地方, 比如說可以打數學符號、插入圖片、做超連結。

# %% [markdown]
# 定義一個函數 $f(x) = x^3 - 2x + 5$
#
# $$L = \int_a^b f(x) \, dx$$

# %% [markdown]
# 網頁連結 [連結到 Google](https://www.google.com)

# %%
# %ls
# Out:
# 01 Jupyter Notebook 環境.ipynb  dragon.png  README.md

# %% [markdown]
# 今天畫了一個插圖:
#
# ![龍](dragon.png)

# %% [markdown]
# ### 畫圖

# %%
y = [34, 12, 88, -5, 67, 25]

# %%
plt.plot(y)

# %%
np.random.randn(20)
# Out:
# array([-0.89756735, -0.70445526,  0.28403657,  0.42858713, -0.24624338,
#         1.12911609, -1.73820651, -0.1282666 , -0.38807804,  0.28664328,
#        -1.59348229,  0.47092799,  0.52334762,  0.94628117,  0.31592191,
#        -2.12850638,  0.66421751,  0.90516444, -0.98296532, -0.71725286])

# %%
y = np.random.randn(200)

# %%
y.mean()
# Out:
# -0.03797033660836623

# %%
y.std()
# Out:
# 0.9172159285953169

# %%
plt.plot(y)

# %% [markdown]
# #### plot 用法
#
#    plt.plot(X, Y)
#
# [(0.2, -5), (1.1, 3), (2, 4), (2.5, 7), (3, -2)]

# %%
x = [0.2, 1.1, 2, 2.5, 3]
y = [-5, 3, 4, 7, -2]

# %%
plt.plot(x, y)

# %%
plt.scatter(x, y)

# %% [markdown]
# ### numpy array

# %%
y = np.array([12, -5, 37, -45, 12, 44])

# %%
y
# Out:
# array([ 12,  -5,  37, -45,  12,  44])

# %%
y.mean()
# Out:
# 9.166666666666666

# %%
y.std()
# Out:
# 29.265546675608544

# %%
x = np.random.randn(100)
y = np.random.randn(100)

# %%
plt.scatter(x, y)

# %% [markdown]
# #### 畫函數
#
# $$f(x) = \sin(x)$$

# %%
x = np.linspace(-10, 10, 200)

# %%
y = np.sin(x)

# %%
plt.plot(x, y)

# %%
plt.scatter(x, y)

# %%
x = np.linspace(-10, 10, 200)
plt.plot(x, np.sin(x), 'r')
plt.plot(x, np.cos(x), 'g')

# %% [markdown]
# ### Python 函式的寫法

# %%
def ham(x):
    s = x**2
    return s

# %%
ham(3)
# Out:
# 9

# %%
ham(3.1)
# Out:
# 9.610000000000001

# %%
print("hello, world")
# Out:
# hello, world

# %%
def egg(x):
    print(x**2)

# %%
egg(3)
# Out:
# 9

# %%
ham(3)
# Out:
# 9

# %%
b = ham(3)

# %%
b
# Out:
# 9

# %%
c = egg(3)
# Out:
# 9

# %%
c

# %%
print()
