# %% [markdown]
# # 單元1. Python 資料分析主流環境 Jupyter

# %% [markdown]
# ## 1-1 魔術指令
#
# 在 Jupyter 中有許多「魔術指令」, 讓我們更方便的用 Python! 每個魔術指令就是用百分比符號開始, 我們介紹第一個非常有用的
#
#     %cd 資料夾路徑
#
# 熟悉指令列的就知道這就會進入指定資料夾。
#
# 接著我們把標準資料分析主要套件讀進來, 唯一要說明的大概是
#
#     %matplotlib inline
#
# 這是說之後畫出的圖, 直接在我們 Jupyter Notebook 的網頁中呈現出來!

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# 這裡的
#
# * `numpy` 是數值計算的標準套件
# * `matplotlib.pyplot` 是用來畫圖的
# * `pandas` 可以說像是 Python 中的 Excel
#
# 更重要的是, 雖然沒有規定, 但我們引用法都是「標準」引用法。這樣引用會讓人覺得你果然是行家。

# %% [markdown]
# ### 【技巧】
#
# 比 `%` 更炫 (更危險) 的是 `!`, 這可以直接執行系統命令列指令!

# %% [markdown]
# ### 【技巧】
#
# 善用 Tab 鍵補完!

# %% [markdown]
# ## 1-2 自由方便的試驗場

# %% [markdown]
# 還可以取好高級的亂數, 從平均數 0, 標準差 1 的常態分佈中取出 n 個數字。
#
#     randn(n)

# %%
np.random.randn(10)
# Out:
# array([-1.16714257,  1.28861505,  1.90462173,  0.36963963, -1.14500584,
#         1.20976069, -1.44059011, -0.00555023,  0.51681248,  0.44081293])

# %% [markdown]
# 當然可以直接畫出來。

# %%
plt.plot(np.random.randn(100))

# %% [markdown]
# `plot` 標準用法就是把
#
# $$(x_1, y_1), (x_2, y_2), \ldots (x_n, y_n)$$
#
# 幾個點點上, 用線段連起來 (也就是折線圖)。指令的下法是把 x, y 座標分別收集起來:
#
# $$x = [x_1, x_2, \ldots, x_n]$$
#
# $$y = [y_1, y_2, \ldots, y_n]$$
#
# 然後用
#
#     plot(x,y)
#
# 畫出來。

# %% [markdown]
# 例如, 我們要畫出 (-2, 3), (1, -5), (2.7, 6), (3.3, 0) 幾個點連成的折線圖。

# %%
x = [-2, 1, 2.7, 3.3]
y = [3, -5, 6, 0]

# %%
plt.plot(x,y)

# %% [markdown]
# ### 【技巧】 `zip` 和 `upzip`
#
# 有時我們這種
#
# $$x = [x_1, x_2, \ldots, x_n]$$
#
# $$y = [y_1, y_2, \ldots, y_n]$$
#
# 表示的資料, 想換成
#
# $$(x_1, y_1), (x_2, y_2), \ldots (x_n, y_n)$$
#
# 這要怎麼做呢?

# %%
list(zip(x,y))
# Out:
# [(-2, 3), (1, -5), (2.7, 6), (3.3, 0)]

# %% [markdown]
# 是不是很簡單? 再來如果我們本來是上面這種形式的資料, 怎麼把 x, y 座標分開呢? 非常神的居然還是 `zip`!

# %%
points = [(-2, 3), (1, -5), (2.7, 6), (3.3, 0)]

# %%
list(zip(*points))
# Out:
# [(-2, 1, 2.7, 3.3), (3, -5, 6, 0)]

# %% [markdown]
# 所以...

# %%
x, y = list(zip(*points))

# %%
x
# Out:
# (-2, 1, 2.7, 3.3)

# %%
y
# Out:
# (3, -5, 6, 0)

# %% [markdown]
# ## 1-3 親切的輔助系統
#
# * Tab 補完神鍵
# * 函數打完不知怎麼用, 可以按
#
# ![Shift-Tab](images/shift_tab.png)

# %% [markdown]
# ## 1-4 用 Markdown 做筆記
#
# Cell 可以選 `Markdown` 模式, 就可以用 `Markdown` 語法做筆記。

# %% [markdown]
# ### 【重點】標題
#
# `# 最大標題`
# # 最大標題
#
# `## 副標題`
# ## 副標題
#
# ...

# %% [markdown]
# ### 【重點】分點說明
#
# 我們要學以下幾個套件:
#
# * `matplotlib`
# * `numpy`
# * `pandas`
# * `scikit-learn`

# %% [markdown]
# ### 【重點】程式碼
#
# 顯示程式碼有幾種方式。
#
# #### [1] 前面有若干空白
#
#     for i in range(10):
#         print(i)
#
# #### [2] 內文可以用斜引號
#
#     `matplotlib`
#
# #### [3] 還可以用 3 個引號外加語言
#
#     ```python
#     for i in range(10):
#         print(i)
#     ```
#
# ```python
# for i in range(10):
#     print(i)
# ```

# %% [markdown]
# ### 【重點】插入網頁
#
# 格式如下
#
#     [網頁名稱](URL)
#
# 例如
#
#     [炎龍老師的網頁](http://yenlung.km.nccu.edu.tw)
#
# 結果: [炎龍老師的網頁](http://yenlung.km.nccu.edu.tw)

# %% [markdown]
# ### 【重點】插入圖片
#
#     ![圖片名稱](圖片路徑)
#
# 例如
#
#     ![Happy Python](images/happy_python.png)
#
# ![Happy Python](images/happy_python.png)

# %% [markdown]
# ### 【重點】輸入數學符號
#
# 支援 LaTeX 指令。
#
# #### 隨文模式
#
# 例如
#
#     設我們有函數 $f(x) = x^3 - 2x + 5$。
#
# [結果] 設我們有函數 $f(x) = x^3 - 2x + 5$。
#
# #### 展式模式
#
# 例如
#
#     $$\int_a^b f(x) \, dx$$
#
# $$\int_a^b f(x) \, dx$$

# %% [markdown]
# ## 1-5 超炫的互動
#
# Jupyter Notebook 的互動模式, 提供非常好的科學計算 GUI 實驗場!

# %% [markdown]
# ### 定義一個函數, 就能互動!

# %%
from ipywidgets import interact

# %%
def f(x):
    print(x)

# %% [markdown]
# ### 【範例】數值滑桿

# %%
interact(f, x=3)
# Out:
# A Jupyter Widget
# <function __main__.f>

# %% [markdown]
# 也可以是浮點數。

# %%
interact(f, x=3.)
# Out:
# A Jupyter Widget
# <function __main__.f>

# %% [markdown]
# 還可以設範圍。

# %%
interact(f, x=(1,10))
# Out:
# A Jupyter Widget
# <function __main__.f>

# %% [markdown]
# ### 【範例】文字框

# %%
interact(f, x="你好")
# Out:
# A Jupyter Widget
# <function __main__.f>

# %% [markdown]
# ### 【範例】下拉式選單之一

# %%
interact(f, x=["台北", "台中", "台南"])
# Out:
# A Jupyter Widget
# <function __main__.f>

# %% [markdown]
# ### 【範例】下拉式選單之二

# %%
interact(f, x={"台北":1, "台中":2, "台南":3})
# Out:
# A Jupyter Widget
# <function __main__.f>

# %% [markdown]
# ### 【例子】會跑的蟲
#
# 順便示範怎麼樣設預設值。

# %%
def move(n=1):
    print(" "*n + "oooo")

interact(move, n=(1,50))
# Out:
# A Jupyter Widget
# <function __main__.move>

# %% [markdown]
# ### 【例子】視覺化的互動
#
# 記得要加 `plt.show()`, 畫圖指令之後會學。

# %%
x = np.linspace(-5, 5, 1000)

def draw(n=1):   
    y = np.sinc(n*x)
    plt.plot(x,y, lw=3)
    plt.show()

# %%
interact(draw, n=(1,15))
# Out:
# A Jupyter Widget
# <function __main__.draw>
