# %%
1+1
# Out:
# 2

# %%
20+30*(20+77)
# Out:
# 2930

# %%
7/3
# Out:
# 2.3333333333333335

# %%
2**3
# Out:
# 8

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
sin(1)
# Out:
# 0.8414709848078965

# %%
pi
# Out:
# 3.141592653589793

# %%
randn(20)
# Out:
# array([ 0.06076915, -1.02663504,  0.40005044,  1.05840513,  1.47744135,
#         0.77983166, -2.51401343,  1.45610282,  2.2210652 ,  0.47874775,
#         1.07871101, -0.49565892, -0.90602644, -2.75252245, -1.15124981,
#        -1.5297932 ,  0.23882179,  0.45559018, -1.19135565,  0.68707522])

# %%
plot(randn(100))

# %%
plot([3, -5, 2, 11.7, -8])

# %%
plot([0, 0.3, 0.8, 1.4, 2], [1.2, 2, -1.7, 5, -3])
